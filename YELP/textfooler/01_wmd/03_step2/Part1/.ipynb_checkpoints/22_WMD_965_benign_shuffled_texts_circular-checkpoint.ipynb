# %%
import numpy as np
import pandas as pd
from scipy import sparse
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from gensim.models import KeyedVectors

word2vec = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
from nltk.corpus import stopwords

# Removing stop words
stop_words = stopwords.words('english')

# %% [markdown]
# ### Benign Texts (960 texts)

# %%
my_benign = []
f = open('22_benign_shuffled','r')

for line in f:
    my_benign.append(line.strip())
len(my_benign)
# Out:
# 966

# %%
ben_tokenized = []
for sentence in my_benign:
    sentence = sentence.lower().split()
    ben_tokenized.append(sentence)

# %%
ben_tokenized_new = []
for line in ben_tokenized:
    line = [w for w in line if w not in stop_words]
    ben_tokenized_new.append(line)

# %%
len(ben_tokenized_new)
# Out:
# 966

# %%
import time

# %%
ben_score = []
start = time.time()
for i in range(0,len(ben_tokenized_new)-1):
    for j in range(0,len(ben_tokenized_new)-1):
        if i != j:
            distance = word2vec.wmdistance(ben_tokenized_new[i], ben_tokenized_new[j])
            ben_score.append(distance)
            #print(f'Distance between sentence {i} and sentence {j} is: {distance}')
end = time.time()

# %%
time1 = end - start
print(f"Runtime for Benign Shuffle Distances is {time1/60} minutes i.e., {time1/3600} hours")
# Out:
# Runtime for Benign Shuffle Distances is 56.05840137799581 minutes i.e., 0.9343066896332635 hours

# %%
ben_score_new = []
import math
for i in ben_score:
    if i != math.inf:
        ben_score_new.append(i)
max(ben_score_new)
# Out:
# 4.599524470285019

# %%
# Density Plot and Histogram of all benign scores

start = time.time()
sns.distplot(ben_score_new, hist=False, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True , 'linewidth': 3})
end = time.time()
plt.title('Density Plot for Benign Shuffled Circular Similarity Scores')
plt.xlabel('Word Mover Distance')
plt.ylabel('Density')

time2 = end - start

# %%
print(f"Runtime for Plotting Benign Shuffle Distances is {time2} seconds")
# Out:
# Runtime for Plotting Benign Shuffle Distances is 3.576470375061035 seconds

# %%
# Density Plot and Histogram of all benign scores

sns.distplot(ben_score_new, hist=False, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True , 'linewidth': 3}).set(xlim=(-1.25, 5.25),ylim=(0, 2))

plt.title('Density Plot for Benign Shuffled Circular Similarity Scores')
plt.xlabel('Word Mover Distance')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
max(ben_score_new)
# Out:
# 4.599524470285019

# %%
all_score = []
start = time.time()
for i in ben_score_new:
    all_score.append(i)
end = time.time()

time3 = end - start

# %%
print(f"Runtime for copying Benign Shuffle Distances is {time3} seconds")
# Out:
# Runtime for copying Benign Shuffle Distances is 0.09190869331359863 seconds

# %%
max(all_score)
# Out:
# 4.599524470285019

# %%
len(all_score)
# Out:
# 928332

# %%
start = time.time()

min_val = min(all_score)
max_val = max(all_score)
for i, val in enumerate(all_score):
    all_score[i] = (val-min_val) / (max_val - min_val)
end = time.time()

time4 = end - start

# %%
print(f"Runtime for normalizing Benign Shuffle Distances is {time4} seconds")
# Out:
# Runtime for normalizing Benign Shuffle Distances is 0.2403564453125 seconds

# %%
len(all_score)
# Out:
# 928332

# %%
max(all_score)
# Out:
# 1.0

# %%
start = time.time()
sns.distplot(all_score, hist=False, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True , 'linewidth': 3})
end = time.time()
plt.title('Density Plot for Benign Shuffled Similarity Scores')
plt.xlabel('Word Mover Distance Normalized')
plt.ylabel('Density')

time5 = end - start

# %%
print(f"Runtime for plotting normalized Benign Shuffle Distances is {time5} seconds")
# Out:
# Runtime for plotting normalized Benign Shuffle Distances is 3.2471444606781006 seconds

# %%
sns.distplot(all_score, hist=False, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'shade': True , 'linewidth': 3}).set(xlim=(-0.25, 1.25),ylim=(0, 10))

plt.title('Density Plot for Benign Shuffled Similarity Scores')
plt.xlabel('Word Mover Distance Normalized')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
with open('12_ben100_shuffle_circular_new_norm.txt', 'w') as f:
    for item in all_score:
        f.write("%s\n" % item)
